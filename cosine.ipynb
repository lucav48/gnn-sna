# %%
import pandas as pd

# %% [markdown]
# # wisconsin

# %%
df1=pd.read_csv('wisconsin/wisconsin_cosine_weights1.csv')
df25=pd.read_csv('wisconsin/wisconsin_cosine_weights25.csv')
df=pd.read_csv('wisconsin/wisconsin_cosine_weights.csv')

# %%
df1['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df25['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df['weight'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cornell

# %%
df1=pd.read_csv('cornell/cornell_cosine_weights1.csv')
df50=pd.read_csv('cornell/cornell_cosine_weight50.csv')
df=pd.read_csv('cornell/cornell_cosine_weights.csv')

# %%
df1['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df50['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df['weight'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # texas

# %%
df1=pd.read_csv('texas/texas_cosine_weights1.csv')
df50=pd.read_csv('texas/texas_cosine_weights50.csv')
df=pd.read_csv('texas/texas_cosine_weights.csv')

# %%
df1['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df50['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df['weight'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cora

# %%
df1=pd.read_csv('cora/cora_cosine_weights1.csv')
df25=pd.read_csv('cora/cora_cosine_weights25.csv')
df=pd.read_csv('cora/cora_cosine_weights.csv')

# %%
df1['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df25['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df['weight'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # citeseer

# %%
df1=pd.read_csv('citeseer/citeseer_cosine_weights1.csv')
df15=pd.read_csv('citeseer/citeseer_cosine_weights15.csv')
df=pd.read_csv('citeseer/citeseer_cosine_weights.csv')

# %%
df1['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df15['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df['weight'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # pubmed

# %%
df1=pd.read_csv('pubmed/pubmed_cosine_weights1.csv')
df10=pd.read_csv('pubmed/pubmed_cosine_weights10.csv')
df=pd.read_csv('pubmed/pubmed_cosine_weights.csv')

# %%
df1['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df10['weight'].hist()
# Out:
# <AxesSubplot:>

# %%
df['weight'].hist()
# Out:
# <AxesSubplot:>
